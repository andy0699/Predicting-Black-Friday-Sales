# %% [markdown]
# # Black Friday Sales

# %% [markdown]
# ## Group:1
#    ## Archita Palkar
#    ## Apurv Prakash
#    ## Aniket Patole

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
traindf = pd.read_csv(r"traindf.csv")
testdf = pd.read_csv(r"testdf.csv")

# %%
traindf
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 15      1000006  P00190242      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# 17      1000006  P00058442      F  51-55           9             A
# 18      1000007  P00036842      M  36-45           1             B
# 19      1000008  P00249542      M  26-35          12             C
# 20      1000008  P00220442      M  26-35          12             C
# 21      1000008  P00156442      M  26-35          12             C
# 22      1000008  P00213742      M  26-35          12             C
# 23      1000008  P00214442      M  26-35          12             C
# 24      1000008  P00303442      M  26-35          12             C
# 25      1000009  P00135742      M  26-35          17             C
# 26      1000009  P00039942      M  26-35          17             C
# 27      1000009  P00161442      M  26-35          17             C
# 28      1000009  P00078742      M  26-35          17             C
# 29      1000010  P00085942      F  36-45           1             B
# ...         ...        ...    ...    ...         ...           ...
# 550038  1005995  P00375436      F  36-45           1             C
# 550039  1005996  P00371644      F  26-35           0             B
# 550040  1005997  P00370853      F  26-35           7             A
# 550041  1006000  P00371644      M  46-50          17             B
# 550042  1006002  P00371644      M  51-55           0             C
# 550043  1006003  P00370293      F  46-50          17             C
# 550044  1006004  P00370853      F  26-35          15             C
# 550045  1006005  P00371644      F  26-35           5             C
# 550046  1006006  P00375436      F   0-17           0             C
# 550047  1006009  P00372445      F  26-35          12             C
# 550048  1006010  P00371644      M  36-45           0             C
# 550049  1006011  P00375436      M  36-45          15             C
# 550050  1006012  P00371644      M  36-45          15             C
# 550051  1006013  P00375436      F  26-35          20             C
# 550052  1006016  P00375436      M  46-50           1             B
# 550053  1006017  P00371644      F  36-45           7             B
# 550054  1006018  P00370293      M  36-45           1             C
# 550055  1006019  P00372445      M  26-35           0             A
# 550056  1006022  P00375436      M  26-35          17             C
# 550057  1006023  P00370853      M  26-35           0             C
# 550058  1006024  P00372445      M  26-35          12             A
# 550059  1006025  P00370853      F  26-35           1             B
# 550060  1006026  P00371644      M  36-45           6             C
# 550061  1006029  P00372445      F  26-35           1             C
# 550062  1006032  P00372445      M  46-50           7             A
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# 5                               3               0                   1
# 6                               2               1                   1
# 7                               2               1                   1
# 8                               2               1                   1
# 9                               1               1                   8
# 10                              1               1                   5
# 11                              1               1                   8
# 12                              1               1                   8
# 13                              1               1                   1
# 14                              1               0                   5
# 15                              1               0                   4
# 16                              1               0                   2
# 17                              1               0                   5
# 18                              1               1                   1
# 19                             4+               1                   1
# 20                             4+               1                   5
# 21                             4+               1                   8
# 22                             4+               1                   8
# 23                             4+               1                   8
# 24                             4+               1                   1
# 25                              0               0                   6
# 26                              0               0                   8
# 27                              0               0                   5
# 28                              0               0                   5
# 29                             4+               1                   2
# ...                           ...             ...                 ...
# 550038                          2               1                  20
# 550039                          1               1                  20
# 550040                          3               0                  19
# 550041                          2               1                  20
# 550042                          1               1                  20
# 550043                          1               0                  19
# 550044                          2               0                  19
# 550045                          2               1                  20
# 550046                          1               0                  20
# 550047                          3               0                  20
# 550048                          1               0                  20
# 550049                          3               0                  20
# 550050                         4+               1                  20
# 550051                          3               0                  20
# 550052                          1               1                  20
# 550053                          1               0                  20
# 550054                          3               0                  19
# 550055                         4+               0                  20
# 550056                         4+               0                  20
# 550057                          2               1                  19
# 550058                          0               1                  20
# 550059                          1               0                  19
# 550060                          1               1                  20
# 550061                          1               1                  20
# 550062                          3               0                  20
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# 5                      2.0                 NaN     15227
# 6                      8.0                17.0     19215
# 7                     15.0                 NaN     15854
# 8                     16.0                 NaN     15686
# 9                      NaN                 NaN      7871
# 10                    11.0                 NaN      5254
# 11                     NaN                 NaN      3957
# 12                     NaN                 NaN      6073
# 13                     2.0                 5.0     15665
# 14                     8.0                14.0      5378
# 15                     5.0                 NaN      2079
# 16                     3.0                 4.0     13055
# 17                    14.0                 NaN      8851
# 18                    14.0                16.0     11788
# 19                     5.0                15.0     19614
# 20                    14.0                 NaN      8584
# 21                     NaN                 NaN      9872
# 22                     NaN                 NaN      9743
# 23                     NaN                 NaN      5982
# 24                     8.0                14.0     11927
# 25                     8.0                 NaN     16662
# 26                     NaN                 NaN      5887
# 27                    14.0                 NaN      6973
# 28                     8.0                14.0      5391
# 29                     4.0                 8.0     16352
# ...                    ...                 ...       ...
# 550038                 NaN                 NaN       596
# 550039                 NaN                 NaN       595
# 550040                 NaN                 NaN        26
# 550041                 NaN                 NaN       488
# 550042                 NaN                 NaN       243
# 550043                 NaN                 NaN        48
# 550044                 NaN                 NaN        62
# 550045                 NaN                 NaN       252
# 550046                 NaN                 NaN       236
# 550047                 NaN                 NaN       244
# 550048                 NaN                 NaN       591
# 550049                 NaN                 NaN       473
# 550050                 NaN                 NaN       368
# 550051                 NaN                 NaN       489
# 550052                 NaN                 NaN       239
# 550053                 NaN                 NaN       371
# 550054                 NaN                 NaN        60
# 550055                 NaN                 NaN       238
# 550056                 NaN                 NaN       254
# 550057                 NaN                 NaN        61
# 550058                 NaN                 NaN       121
# 550059                 NaN                 NaN        48
# 550060                 NaN                 NaN       494
# 550061                 NaN                 NaN       599
# 550062                 NaN                 NaN       473
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
testdf
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# 5       1000013  P00350442      M  46-50           1             C
# 6       1000013  P00155442      M  46-50           1             C
# 7       1000013   P0094542      M  46-50           1             C
# 8       1000015  P00161842      M  26-35           7             A
# 9       1000022  P00067942      M  18-25          15             A
# 10      1000026  P00046742      M  26-35           7             B
# 11      1000026  P00040042      M  26-35           7             B
# 12      1000026  P00196542      M  26-35           7             B
# 13      1000026  P00004542      M  26-35           7             B
# 14      1000028  P00159542      F  26-35           1             C
# 15      1000029  P00111542      M  36-45           7             C
# 16      1000033  P00121042      M  46-50           3             A
# 17      1000033  P00344442      M  46-50           3             A
# 18      1000034  P00265242      F  18-25           0             A
# 19      1000035   P0096642      M  46-50           1             C
# 20      1000036  P00303042      M  26-35           3             B
# 21      1000036  P00059642      M  26-35           3             B
# 22      1000042  P00030842      M  26-35           8             C
# 23      1000045  P00346442      F  46-50          16             A
# 24      1000045  P00357242      F  46-50          16             A
# 25      1000045  P00284742      F  46-50          16             A
# 26      1000048  P00110842      M  26-35           4             B
# 27      1000048  P00251642      M  26-35           4             B
# 28      1000053  P00136742      M  26-35           0             B
# 29      1000053   P0097342      M  26-35           0             B
# ...         ...        ...    ...    ...         ...           ...
# 233569  1005996  P00184242      F  26-35           0             B
# 233570  1005996  P00045342      F  26-35           0             B
# 233571  1006001  P00124642      F  26-35           7             A
# 233572  1006002  P00121142      M  51-55           0             C
# 233573  1006002  P00233542      M  51-55           0             C
# 233574  1006002  P00226342      M  51-55           0             C
# 233575  1006002  P00284842      M  51-55           0             C
# 233576  1006003  P00313342      F  46-50          17             C
# 233577  1006010  P00223542      M  36-45           0             C
# 233578  1006013  P00020342      F  26-35          20             C
# 233579  1006016  P00014842      M  46-50           1             B
# 233580  1006016  P00109542      M  46-50           1             B
# 233581  1006018  P00071442      M  36-45           1             C
# 233582  1006021  P00112542      M  26-35          12             B
# 233583  1006021  P00003442      M  26-35          12             B
# 233584  1006023  P00262242      M  26-35           0             C
# 233585  1006025  P00161142      F  26-35           1             B
# 233586  1006026  P00110742      M  36-45           6             C
# 233587  1006028  P00162442      M  18-25           4             A
# 233588  1006030  P00129842      M  26-35          17             C
# 233589  1006030  P00241442      M  26-35          17             C
# 233590  1006032  P00252442      M  46-50           7             A
# 233591  1006033  P00127642      M  51-55          13             B
# 233592  1006035  P00135742      F  26-35           1             C
# 233593  1006036  P00255442      F  26-35          15             B
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# 5                               3               1                   2
# 6                               3               1                   1
# 7                               3               1                   2
# 8                               1               0                  10
# 9                              4+               0                   5
# 10                              2               1                   1
# 11                              2               1                   5
# 12                              2               1                   5
# 13                              2               1                   5
# 14                              2               1                  10
# 15                              1               0                   2
# 16                              1               1                  15
# 17                              1               1                   5
# 18                              0               0                   5
# 19                             4+               1                   2
# 20                              0               0                   5
# 21                              0               0                   1
# 22                              0               1                   1
# 23                              1               1                   1
# 24                              1               1                   5
# 25                              1               1                   5
# 26                              3               1                   1
# 27                              3               1                   1
# 28                              1               0                   1
# 29                              1               0                   1
# ...                           ...             ...                 ...
# 233569                          1               1                   9
# 233570                          1               1                   1
# 233571                          0               1                  16
# 233572                          1               1                   8
# 233573                          1               1                   1
# 233574                          1               1                  11
# 233575                          1               1                   1
# 233576                          1               0                   5
# 233577                          1               0                   1
# 233578                          3               0                   1
# 233579                          1               1                   1
# 233580                          1               1                   8
# 233581                          3               0                  15
# 233582                          2               1                   1
# 233583                          2               1                   4
# 233584                          2               1                   1
# 233585                          1               0                  11
# 233586                          1               1                   1
# 233587                         4+               0                   1
# 233588                          1               1                   6
# 233589                          1               1                   2
# 233590                          3               0                   8
# 233591                          1               1                   1
# 233592                          3               0                   6
# 233593                         4+               1                   8
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 0                     11.0                 NaN
# 1                      5.0                 NaN
# 2                     14.0                 NaN
# 3                      9.0                 NaN
# 4                      5.0                12.0
# 5                      3.0                15.0
# 6                     11.0                15.0
# 7                      4.0                 9.0
# 8                     13.0                16.0
# 9                     14.0                 NaN
# 10                     2.0                15.0
# 11                     NaN                 NaN
# 12                     8.0                14.0
# 13                     8.0                 NaN
# 14                    15.0                16.0
# 15                    17.0                 NaN
# 16                     NaN                 NaN
# 17                     8.0                14.0
# 18                     8.0                 NaN
# 19                     3.0                 4.0
# 20                     NaN                 NaN
# 21                     2.0                 3.0
# 22                     2.0                15.0
# 23                     2.0                14.0
# 24                     NaN                 NaN
# 25                    12.0                 NaN
# 26                     2.0                 5.0
# 27                     2.0                 4.0
# 28                    14.0                16.0
# 29                    15.0                16.0
# ...                    ...                 ...
# 233569                15.0                 NaN
# 233570                 5.0                17.0
# 233571                 NaN                 NaN
# 233572                 NaN                 NaN
# 233573                15.0                 NaN
# 233574                15.0                 NaN
# 233575                 8.0                17.0
# 233576                 NaN                 NaN
# 233577                 8.0                17.0
# 233578                 2.0                 NaN
# 233579                 2.0                 5.0
# 233580                14.0                17.0
# 233581                17.0                 NaN
# 233582                11.0                15.0
# 233583                 5.0                 8.0
# 233584                11.0                16.0
# 233585                 NaN                 NaN
# 233586                 2.0                 8.0
# 233587                16.0                 NaN
# 233588                 8.0                15.0
# 233589                15.0                 NaN
# 233590                 NaN                 NaN
# 233591                 2.0                15.0
# 233592                 8.0                 NaN
# 233593                 NaN                 NaN
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233599 rows x 11 columns]

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
testdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
# User_ID                       233599 non-null int64
# Product_ID                    233599 non-null object
# Gender                        233599 non-null object
# Age                           233599 non-null object
# Occupation                    233599 non-null int64
# City_Category                 233599 non-null object
# Stay_In_Current_City_Years    233599 non-null object
# Marital_Status                233599 non-null int64
# Product_Category_1            233599 non-null int64
# Product_Category_2            161255 non-null float64
# Product_Category_3            71037 non-null float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
print('Shape: ',traindf.shape)
print('Shape: ',testdf.shape)
# Out:
# Shape:  (550068, 12)
# Shape:  (233599, 11)

# %%
traindf.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
testdf.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %% [markdown]
# # Combining train and test data to avoid repeating preprocessing steps for both dataframes

# %%
traindf['source']='traindf'
testdf['source']='testdf'
data = pd.concat([traindf, testdf], ignore_index = True,sort=False)
data.shape
# Out:
# (783667, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
# User_ID                       783667 non-null int64
# Product_ID                    783667 non-null object
# Gender                        783667 non-null object
# Age                           783667 non-null object
# Occupation                    783667 non-null int64
# City_Category                 783667 non-null object
# Stay_In_Current_City_Years    783667 non-null object
# Marital_Status                783667 non-null int64
# Product_Category_1            783667 non-null int64
# Product_Category_2            537685 non-null float64
# Product_Category_3            237858 non-null float64
# Purchase                      550068 non-null float64
# source                        783667 non-null object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 77.7+ MB

# %% [markdown]
# # Missing values

# %% [markdown]
# ### Filling the missing values with zero

# %%
data.Product_Category_2.fillna(0, inplace = True)
data.Product_Category_3.fillna(0, inplace = True)

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 15      1000006  P00190242      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# 17      1000006  P00058442      F  51-55           9             A
# 18      1000007  P00036842      M  36-45           1             B
# 19      1000008  P00249542      M  26-35          12             C
# 20      1000008  P00220442      M  26-35          12             C
# 21      1000008  P00156442      M  26-35          12             C
# 22      1000008  P00213742      M  26-35          12             C
# 23      1000008  P00214442      M  26-35          12             C
# 24      1000008  P00303442      M  26-35          12             C
# 25      1000009  P00135742      M  26-35          17             C
# 26      1000009  P00039942      M  26-35          17             C
# 27      1000009  P00161442      M  26-35          17             C
# 28      1000009  P00078742      M  26-35          17             C
# 29      1000010  P00085942      F  36-45           1             B
# ...         ...        ...    ...    ...         ...           ...
# 783637  1005996  P00184242      F  26-35           0             B
# 783638  1005996  P00045342      F  26-35           0             B
# 783639  1006001  P00124642      F  26-35           7             A
# 783640  1006002  P00121142      M  51-55           0             C
# 783641  1006002  P00233542      M  51-55           0             C
# 783642  1006002  P00226342      M  51-55           0             C
# 783643  1006002  P00284842      M  51-55           0             C
# 783644  1006003  P00313342      F  46-50          17             C
# 783645  1006010  P00223542      M  36-45           0             C
# 783646  1006013  P00020342      F  26-35          20             C
# 783647  1006016  P00014842      M  46-50           1             B
# 783648  1006016  P00109542      M  46-50           1             B
# 783649  1006018  P00071442      M  36-45           1             C
# 783650  1006021  P00112542      M  26-35          12             B
# 783651  1006021  P00003442      M  26-35          12             B
# 783652  1006023  P00262242      M  26-35           0             C
# 783653  1006025  P00161142      F  26-35           1             B
# 783654  1006026  P00110742      M  36-45           6             C
# 783655  1006028  P00162442      M  18-25           4             A
# 783656  1006030  P00129842      M  26-35          17             C
# 783657  1006030  P00241442      M  26-35          17             C
# 783658  1006032  P00252442      M  46-50           7             A
# 783659  1006033  P00127642      M  51-55          13             B
# 783660  1006035  P00135742      F  26-35           1             C
# 783661  1006036  P00255442      F  26-35          15             B
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# 5                               3               0                   1
# 6                               2               1                   1
# 7                               2               1                   1
# 8                               2               1                   1
# 9                               1               1                   8
# 10                              1               1                   5
# 11                              1               1                   8
# 12                              1               1                   8
# 13                              1               1                   1
# 14                              1               0                   5
# 15                              1               0                   4
# 16                              1               0                   2
# 17                              1               0                   5
# 18                              1               1                   1
# 19                             4+               1                   1
# 20                             4+               1                   5
# 21                             4+               1                   8
# 22                             4+               1                   8
# 23                             4+               1                   8
# 24                             4+               1                   1
# 25                              0               0                   6
# 26                              0               0                   8
# 27                              0               0                   5
# 28                              0               0                   5
# 29                             4+               1                   2
# ...                           ...             ...                 ...
# 783637                          1               1                   9
# 783638                          1               1                   1
# 783639                          0               1                  16
# 783640                          1               1                   8
# 783641                          1               1                   1
# 783642                          1               1                  11
# 783643                          1               1                   1
# 783644                          1               0                   5
# 783645                          1               0                   1
# 783646                          3               0                   1
# 783647                          1               1                   1
# 783648                          1               1                   8
# 783649                          3               0                  15
# 783650                          2               1                   1
# 783651                          2               1                   4
# 783652                          2               1                   1
# 783653                          1               0                  11
# 783654                          1               1                   1
# 783655                         4+               0                   1
# 783656                          1               1                   6
# 783657                          1               1                   2
# 783658                          3               0                   8
# 783659                          1               1                   1
# 783660                          3               0                   6
# 783661                         4+               1                   8
# 783662                         4+               1                   8
# 783663                         4+               1                   5
# 783664                         4+               1                   1
# 783665                         4+               0                  10
# 783666                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase   source
# 0                      0.0                 0.0    8370.0  traindf
# 1                      6.0                14.0   15200.0  traindf
# 2                      0.0                 0.0    1422.0  traindf
# 3                     14.0                 0.0    1057.0  traindf
# 4                      0.0                 0.0    7969.0  traindf
# 5                      2.0                 0.0   15227.0  traindf
# 6                      8.0                17.0   19215.0  traindf
# 7                     15.0                 0.0   15854.0  traindf
# 8                     16.0                 0.0   15686.0  traindf
# 9                      0.0                 0.0    7871.0  traindf
# 10                    11.0                 0.0    5254.0  traindf
# 11                     0.0                 0.0    3957.0  traindf
# 12                     0.0                 0.0    6073.0  traindf
# 13                     2.0                 5.0   15665.0  traindf
# 14                     8.0                14.0    5378.0  traindf
# 15                     5.0                 0.0    2079.0  traindf
# 16                     3.0                 4.0   13055.0  traindf
# 17                    14.0                 0.0    8851.0  traindf
# 18                    14.0                16.0   11788.0  traindf
# 19                     5.0                15.0   19614.0  traindf
# 20                    14.0                 0.0    8584.0  traindf
# 21                     0.0                 0.0    9872.0  traindf
# 22                     0.0                 0.0    9743.0  traindf
# 23                     0.0                 0.0    5982.0  traindf
# 24                     8.0                14.0   11927.0  traindf
# 25                     8.0                 0.0   16662.0  traindf
# 26                     0.0                 0.0    5887.0  traindf
# 27                    14.0                 0.0    6973.0  traindf
# 28                     8.0                14.0    5391.0  traindf
# 29                     4.0                 8.0   16352.0  traindf
# ...                    ...                 ...       ...      ...
# 783637                15.0                 0.0       NaN   testdf
# 783638                 5.0                17.0       NaN   testdf
# 783639                 0.0                 0.0       NaN   testdf
# 783640                 0.0                 0.0       NaN   testdf
# 783641                15.0                 0.0       NaN   testdf
# 783642                15.0                 0.0       NaN   testdf
# 783643                 8.0                17.0       NaN   testdf
# 783644                 0.0                 0.0       NaN   testdf
# 783645                 8.0                17.0       NaN   testdf
# 783646                 2.0                 0.0       NaN   testdf
# 783647                 2.0                 5.0       NaN   testdf
# 783648                14.0                17.0       NaN   testdf
# 783649                17.0                 0.0       NaN   testdf
# 783650                11.0                15.0       NaN   testdf
# 783651                 5.0                 8.0       NaN   testdf
# 783652                11.0                16.0       NaN   testdf
# 783653                 0.0                 0.0       NaN   testdf
# 783654                 2.0                 8.0       NaN   testdf
# 783655                16.0                 0.0       NaN   testdf
# 783656                 8.0                15.0       NaN   testdf
# 783657                15.0                 0.0       NaN   testdf
# 783658                 0.0                 0.0       NaN   testdf
# 783659                 2.0                15.0       NaN   testdf
# 783660                 8.0                 0.0       NaN   testdf
# 783661                 0.0                 0.0       NaN   testdf
# 783662                 0.0                 0.0       NaN   testdf
# 783663                 8.0                 0.0       NaN   testdf
# 783664                 5.0                12.0       NaN   testdf
# 783665                16.0                 0.0       NaN   testdf
# 783666                 5.0                 0.0       NaN   testdf
#
# [783667 rows x 13 columns]

# %% [markdown]
# # Dropping unecessary columns

# %% [markdown]
# ### Columns 'User_ID' and 'Product_ID' has very less dependency on our target column so we can drop it

# %%
cols = ['User_ID','Product_ID']
data.drop(cols, inplace = True, axis=1)

# %%
data.head()
# Out:
#   Gender   Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0      F  0-17          10             A                          2
# 1      F  0-17          10             A                          2
# 2      F  0-17          10             A                          2
# 3      F  0-17          10             A                          2
# 4      M   55+          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 0.0                 0.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 0.0                 0.0
# 3               0                  12                14.0                 0.0
# 4               0                   8                 0.0                 0.0
#
#    Purchase   source
# 0    8370.0  traindf
# 1   15200.0  traindf
# 2    1422.0  traindf
# 3    1057.0  traindf
# 4    7969.0  traindf

# %% [markdown]
# # Data Types

# %% [markdown]
# ### 'Product_Category_2' and 'Product_Category_3' has floating point numbers which can be converted into int type

# %%
print('Product cat1:',data['Product_Category_1'].unique())
print('Product cat2:',data['Product_Category_2'].unique())
print('Product cat3:',data['Product_Category_3'].unique())
# Out:
# Product cat1: [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]
# Product cat2: [ 0.  6. 14.  2.  8. 15. 16. 11.  5.  3.  4. 12.  9. 10. 17. 13.  7. 18.]
# Product cat3: [ 0. 14. 17.  5.  4. 16. 15.  8.  9. 13.  6. 12.  3. 18. 11. 10.]

# %%
data.dtypes
# Out:
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# source                         object
# dtype: object

# %%
data.Product_Category_2 = data.Product_Category_2.astype(int)
data.Product_Category_3 = data.Product_Category_3.astype(int)

# %% [markdown]
# # Using Label encoder for categorical values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE_Gender = LabelEncoder()
data['Gender']=LE_Gender.fit_transform(data['Gender'])

# %%
LE_Gender.classes_
# Out:
# array(['F', 'M'], dtype=object)

# %%
LE_Age = LabelEncoder()
data['Age']=LE_Age.fit_transform(data['Age'])

# %%
LE_Age.classes_
# Out:
# array(['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+'],
#       dtype=object)

# %%
LE_City = LabelEncoder()
data['City_Category']= LE_City.fit_transform(data['City_Category'])

# %%
LE_City.classes_
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
data[['Stay_In_Current_City_Years']] = data[['Stay_In_Current_City_Years']].replace('4+' , 4 )

# %%
data.Stay_In_Current_City_Years = data.Stay_In_Current_City_Years.astype(int)

# %%
data.head()
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0    0          10              0                           2
# 1       0    0          10              0                           2
# 2       0    0          10              0                           2
# 3       0    0          10              0                           2
# 4       1    6          16              2                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                   0                   0
# 1               0                   1                   6                  14
# 2               0                  12                   0                   0
# 3               0                  12                  14                   0
# 4               0                   8                   0                   0
#
#    Purchase   source
# 0    8370.0  traindf
# 1   15200.0  traindf
# 2    1422.0  traindf
# 3    1057.0  traindf
# 4    7969.0  traindf

# %% [markdown]
# # Outliers

# %%
data[['Product_Category_1','Product_Category_2','Product_Category_3']].plot.box()

# %% [markdown]
# ### We can see that we have outliers above 19 range

# %%
data = data[data['Product_Category_1'] < 19]

# %%
data[['Product_Category_1','Product_Category_2','Product_Category_3']].plot.box()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 779514 entries, 0 to 783666
# Data columns (total 11 columns):
# Gender                        779514 non-null int32
# Age                           779514 non-null int32
# Occupation                    779514 non-null int64
# City_Category                 779514 non-null int32
# Stay_In_Current_City_Years    779514 non-null int32
# Marital_Status                779514 non-null int64
# Product_Category_1            779514 non-null int64
# Product_Category_2            779514 non-null int32
# Product_Category_3            779514 non-null int32
# Purchase                      545915 non-null float64
# source                        779514 non-null object
# dtypes: float64(1), int32(6), int64(3), object(1)
# memory usage: 53.5+ MB

# %% [markdown]
# # Again divide the dataset into train and test resp.

# %%
#Divide into test and train:
traindf = data.loc[data.source=='traindf']
testdf = data.loc[data.source=='testdf']
#Drop unnecessary columns:
testdf.drop('source',axis=1,inplace=True,errors = 'ignore')
traindf.drop('source',axis=1,inplace=True, errors = 'ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
traindf.Purchase = traindf.Purchase.astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
cols = ['Purchase']
testdf.drop(cols, inplace = True, axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545915 entries, 0 to 545914
# Data columns (total 10 columns):
# Gender                        545915 non-null int32
# Age                           545915 non-null int32
# Occupation                    545915 non-null int64
# City_Category                 545915 non-null int32
# Stay_In_Current_City_Years    545915 non-null int32
# Marital_Status                545915 non-null int64
# Product_Category_1            545915 non-null int64
# Product_Category_2            545915 non-null int32
# Product_Category_3            545915 non-null int32
# Purchase                      545915 non-null int32
# dtypes: int32(7), int64(3)
# memory usage: 31.2 MB

# %%
testdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233599 entries, 550068 to 783666
# Data columns (total 10 columns):
# Gender                        233599 non-null int32
# Age                           233599 non-null int32
# Occupation                    233599 non-null int64
# City_Category                 233599 non-null int32
# Stay_In_Current_City_Years    233599 non-null int32
# Marital_Status                233599 non-null int64
# Product_Category_1            233599 non-null int64
# Product_Category_2            233599 non-null int32
# Product_Category_3            233599 non-null int32
# Purchase                      0 non-null float64
# dtypes: float64(1), int32(6), int64(3)
# memory usage: 14.3 MB

# %% [markdown]
# # Data is clean

# %%
from  sklearn.preprocessing import StandardScaler

# %%
sc_X = StandardScaler()
train = sc_X.fit(traindf)
test = sc_X.fit(testdf)

# %%
train
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
test
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
